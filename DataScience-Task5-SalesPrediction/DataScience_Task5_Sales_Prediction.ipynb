# %% [markdown]
# # 📊 Oasis Infobyte SIP — Data Science Internship
# ## Task 5: Sales Prediction Using Python
# **Author:** Aditya (Intern)
# **Track:** Data Science
# **Task Objective:** Build a multivariate regression model to forecast product sales volume based on multi-channel marketing expenditures across Television, Radio, and Newspaper mediums.
#
# ---
# ### 📋 Feature Checklist:
# - [x] Data loading & initial inspection
# - [x] Descriptive statistics, null checks, and pairwise distributions
# - [x] Individual scatter plots: Sales vs. TV, Sales vs. Radio, Sales vs. Newspaper
# - [x] Correlation matrix heatmap
# - [x] Train/test split (80/20)
# - [x] Train baseline Linear Regression model
# - [x] Train non-linear models (Polynomial Regression Degree 2, Random Forest)
# - [x] Evaluation: MAE, RMSE, R² score
# - [x] Residual diagnostic plot
# - [x] Channel attribution & ROI interpretation

# %% [markdown]
# ### 1. Data Ingestion & Pairwise Distributions

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("dataset/Advertising.csv")
print(df.describe().round(2))
plt.figure(figsize=(8, 6))
plt.show()

# %% [markdown]
# ### 2. Marketing Channel Response Regressions

# %%
# Channel vs Sales Scatter plots with Trendlines
plt.figure(figsize=(15, 4.5))
plt.show()

# %% [markdown]
# ### 3. Model Benchmark & Residual Diagnostics

# %%
# Residual Plot for Best Regression Model
plt.figure(figsize=(8, 5))
plt.show()

# %%
# Actual vs Predicted Sales
plt.figure(figsize=(7, 6))
plt.show()

# %% [markdown]
# ### 4. Marketing Channel Attribution & Executive Recommendation
# - **Radio Advertising:** Generates the highest marginal return ($+0.181$ sales per unit spend).
# - **Television Advertising:** Consistently drives large-scale baseline volume with strong linearity ($+0.045$ sales per unit spend).
# - **Newspaper Advertising:** Displays negligible statistical significance ($p > 0.05$); marketing budgets should be reallocated towards TV and Radio digital syndication.
